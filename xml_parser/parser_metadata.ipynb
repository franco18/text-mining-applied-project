# %%
import xmltodict

with open('papers-dc.xml') as fd:
    doc = xmltodict.parse(fd.read())

# %% [markdown]
# Para obtener la identificación

# %%
doc['OAI-PMH']['ListRecords']['record'][0]['header']['identifier'].split(":")[2]
# Out:
# '0704.3504'

# %%
doc['OAI-PMH']['ListRecords']['record'][0]['metadata']['oai_dc:dc']['dc:title']
# Out:
# "Smooth R\\'enyi Entropy of Ergodic Quantum Information Sources"

# %%
doc['OAI-PMH']['ListRecords']['record'][0]['metadata']['oai_dc:dc']['dc:creator']
# Out:
# ['Schoenmakers, Berry', 'Tjoelker, Jilles', 'Tuyls, Pim', 'Verbitskiy, Evgeny']

# %%
doc['OAI-PMH']['ListRecords']['record'][0]['metadata']['oai_dc:dc']['dc:subject']
# Out:
# ['Quantum Physics', 'Computer Science - Information Theory']

# %%
doc['OAI-PMH']['ListRecords']['record'][0]['metadata']['oai_dc:dc']['dc:description']
# Out:
# ['We prove that the average smooth Renyi entropy rate will approach the entropy\nrate of a stationary, ergodic information source, which is equal to the Shannon\nentropy rate for a classical information source and the von Neumann entropy\nrate for a quantum information source.',
#  'Comment: 5 pages, no figures, ISIT 2007']

# %%
def titles(d):
    vals = []
    for a in d['OAI-PMH']['ListRecords']['record']:
        vals.append(a['metadata']['oai_dc:dc']['dc:title'])        
    return vals

# %%
aaa = holi(doc)

# %%
aaa
# Out:
# ["Smooth R\\'enyi Entropy of Ergodic Quantum Information Sources",
#  'Analyzing Design Process and Experiments on the AnITA Generic Tutoring\n  System',
#  'Colour image segmentation by the vector-valued Allen-Cahn phase-field\n  model: a multigrid solution',
#  'Unequal Error Protection: An Information Theoretic Perspective',
#  'On the hitting times of quantum versus random walks',
#  'Coding Theory and Algebraic Combinatorics',
#  'Generating Random Networks Without Short Cycles',
#  'Variations on a theme by Schalkwijk and Kailath',
#  'Rotation Distance is Fixed-Parameter Tractable',
#  'A Linear-Time Approximation Algorithm for Rotation Distance',
#  'The quantum query complexity of certification',
#  'On uncertainty principles in the finite dimensional setting',
#  'Error-and-Erasure Decoding for Block Codes with Feedback',
#  'Joint-sparse recovery from multiple measurements',
#  'Inter Genre Similarity Modelling For Automatic Music Genre\n  Classification',
#  'P != NP Proof',
#  'Universally Composable Quantum Multi-Party Computation',
#  'On the stability of two-chunk file-sharing systems',
#  'MAC Layer Hurdles in BSNs',
#  'On the Development of Low Power MAC Protocol for WBANs',
#  'Towards Power Efficient MAC Protocol for In-Body and On-Body Sensor\n  Networks',
#  'A Study of Implanted and Wearable Body Sensor Networks',
#  'Euclidean versus hyperbolic congestion in idealized versus experimental\n  networks',
#  'Model Selection: Two Fundamental Measures of Coherence and Their\n  Algorithmic Significance',
#  'Self-Reference Ultra-Wideband Systems',
#  'JBotSim, a Tool for Fast Prototyping of Distributed Algorithms in\n  Dynamic Networks',
#  'Combinatorial Bounds and Characterizations of Splitting Authentication\n  Codes',
#  'Efficient Bayesian Learning in Social Networks with Gaussian Estimators',
#  'Having Fun with Lambert W(x) Function',
#  'Delay-rate tradeoff in ergodic interference alignment',
#  'FauxCrypt - A Method of Text Obfuscation',
#  'Optimal Gradient Clock Synchronization in Dynamic Networks',
#  'A Proof for P =? NP Problem',
#  'Why Gabor Frames? Two Fundamental Measures of Coherence and Their Role\n  in Model Selection',
#  'Chi-square-based scoring function for categorization of MEDLINE\n  citations',
#  'Rasch-based high-dimensionality data reduction and class prediction with\n  applications to microarray gene expression data',
#  'Computational complexity of reconstruction and isomorphism testing for\n  designs and line graphs',
#  'The Coarsest Precongruences Respecting Safety and Liveness Properties',
#  'Identification of Parametric Underspread Linear Systems and\n  Super-Resolution Radar',
#  'Some Theorems on the Algorithmic Approach to Probability Theory and\n  Information Theory',
#  'Leaders, Followers, and Community Detectio',
#  'Constructing elliptic curve isogenies in quantum subexponential time',
#  'Bit recycling for scaling random number generators',
#  'Almost Settling the Hardness of Noncommutative Determinant',
#  'Asynchronous Code-Division Random Access Using Convex Optimization',
#  'Restarting Automata with Auxiliary Symbols and Small Lookahead',
#  'Bit-wise Unequal Error Protection for Variable Length Block Codes with\n  Feedback',
#  'A Human-Centric Approach to Group-Based Context-Awareness',
#  "On the Complexity of Newman's Community Finding Approach for Biological\n  and Social Networks",
#  'A generalization of heterochromatic graphs',
#  'A generalization of Hopcroft-Karp algorithm for semi-matchings and\n  covers in bipartite graphs (Maximum semi-matching problem in bipartite\n  graphs)',
#  'Constructive proof of the existence of equilibrium in competitive\n  economy with sequentially locally non-constant excess demand functions',
#  "Constructive proof of the existence of Nash Equilibrium in a finite\n  strategic game with sequentially locally non-constant payoff functions by\n  Sperner's lemma",
#  'Quantum Bayesian implementation',
#  'Quantifier Elimination over Finite Fields Using Gr\\"obner Bases',
#  'Hybrid Deterministic-Stochastic Methods for Data Fitting',
#  'Randomness and Differentiability',
#  'An improved bound on the number of point-surface incidences in three\n  dimensions',
#  'Doubly Robust Smoothing of Dynamical Processes via Outlier Sparsity\n  Constraints',
#  'Tracking Target Signal Strengths on a Grid using Sparsity',
#  'A Modified Cross Correlation Algorithm for Reference-free Image\n  Alignment of Non-Circular Projections in Single-Particle Electron Microscopy',
#  'From Classical to Quantum Shannon Theory',
#  'A framework for coupled deformation-diffusion analysis with application\n  to degradation/healing',
#  'An f-chromatic spanning forest of edge-colored complete bipartite graphs',
#  "Some Properties of R\\'{e}nyi Entropy over Countably Infinite Alphabets",
#  'Sparse Sums of Positive Semidefinite Matrices',
#  'An Efficient Algorithm for Maximum-Entropy Extension of Block-Circulant\n  Covariance Matrices',
#  'Noise effects in the quantum search algorithm from the computational\n  complexity point of view',
#  'Planar and Poly-Arc Lombardi Drawings',
#  'The Complexity of the Empire Colouring Problem',
#  'A Statistically Modelling Method for Performance Limits in Sensor\n  Localization',
#  'Energy Aware Scheduling for Weighted Completion Time and Weighted\n  Tardiness',
#  'Robust inversion via semistochastic dimensionality reduction',
#  'Steps Towards a Theory of Visual Information: Active Perception,\n  Signal-to-Symbol Conversion and the Interplay Between Sensing and Control',
#  'New Methods for Handling Singular Sample Covariance Matrices',
#  'A topological interpretation of the walk distances',
#  'The Distance Function on a Computable Graph',
#  'On a Connection Between Small Set Expansions and Modularity Clustering\n  in Social Networks',
#  'Traffic distributions and independence: permutation invariant random\n  matrices and the three notions of independence',
#  'A Taxation Policy for Maximizing Social Welfare in Networks: A General\n  Framework',
#  'I/O efficient bisimulation partitioning on very large directed acyclic\n  graphs',
#  'On Problems as Hard as CNFSAT',
#  'Scikit-learn: Machine Learning in Python',
#  'Competition through selective inhibitory synchrony',
#  'Verifying Real-time Commit Protocols Using Dense-time Model Checking\n  Technology',
#  'An iterative algorithm for parametrization of shortest length shift\n  registers over finite rings',
#  'Standard decomposition of expansive ergodically supported dynamics',
#  'Refinement Modal Logic',
#  'Lipschitz Parametrization of Probabilistic Graphical Models',
#  'A para-model agent for dynamical systems',
#  'Distributed Private Heavy Hitters',
#  'Strongly universal string hashing is fast',
#  'A Comparison of the Embedding Method to Multi-Parametric Programming,\n  Mixed-Integer Programming, Gradient-Descent, and Hybrid Minimum Principle\n  Based Methods',
#  'A Szemeredi-Trotter type theorem in $\\mathbb{R}^4$',
#  'A Universal Model of Commuting Networks',
#  'Semi-Automatically Extracting FAQs to Improve Accessibility of Software\n  Development Knowledge',
#  'Clique problem, cutting plane proofs and communication complexity',
#  'Effective de Rham Cohomology - The General Case',
#  'The FO^2 alternation hierarchy is decidable',
#  'On the Easiest and Hardest Fitness Functions',
#  'New Combinatorial Construction Techniques for Low-Density Parity-Check\n  Codes and Systematic Repeat-Accumulate Codes',
#  'Deducing Security Goals From Shape Analysis Sentences',
#  'A Constrained Random Demodulator for Sub-Nyquist Sampling',
#  'Opinion formation in time-varying social networks: The case of the\n  naming game',
#  'Approximate Revenue Maximization with Multiple Items',
#  'User-based key frame detection in social web video',
#  'Privacy via the Johnson-Lindenstrauss Transform',
#  'The Cost of Perfection for Matchings in Graphs',
#  'Simple Agents Learn to Find Their Way: An Introduction on Mapping\n  Polygons',
#  'Efficient Video Indexing on the Web: A System that Leverages User\n  Interactions with a Video Player',
#  'A Complete Dichotomy Rises from the Capture of Vanishing Signatures',
#  'Dexpler: Converting Android Dalvik Bytecode to Jimple for Static\n  Analysis with Soot',
#  'Perfect Secrecy Systems Immune to Spoofing Attacks',
#  'Randomized Extended Kaczmarz for Solving Least-Squares',
#  'What Should Developers Be Aware Of? An Empirical Study on the Directives\n  of API Documentation',
#  'Exponential Time Complexity of the Permanent and the Tutte Polynomial',
#  'Computability and analysis: the legacy of Alan Turing',
#  'Total coloring of 1-toroidal graphs of maximum degree at least 11 and no\n  adjacent triangles',
#  'Convergence Rates of Biased Stochastic Optimization for Learning Sparse\n  Ising Models',
#  'Machine Learning that Matters',
#  'Connected Choice and the Brouwer Fixed Point Theorem',
#  'Near-Optimal Online Multiselection in Internal and External Memory',
#  'On logical hierarchies within FO^2-definable languages',
#  'On the computation of zone and double zone diagrams',
#  'Toward Resource-Optimal Consensus over the Wireless Medium',
#  'Java Source-code Clustering: Unifying Syntactic and Semantic Features',
#  'Efficient EM Training of Gaussian Mixtures with Missing Data',
#  'Lambert W Function for Applications in Physics',
#  'Programming Languages for Scientific Computing',
#  'Strategic Learning and the Topology of Social Networks',
#  'Coupling Data Transmission for Multiple-Access Communications',
#  'On Newton-Raphson iteration for multiplicative inverses modulo prime\n  powers',
#  'An empirical study to order citation statistics between subject fields',
#  'Group Model Selection Using Marginal Correlations: The Good, the Bad and\n  the Ugly',
#  'On the Automorphism Group of a Binary Self-dual [120, 60, 24] Code',
#  'A PRQ Search Method for Probabilistic Objects',
#  'Halving Lines and Their Underlying Graphs',
#  'Realizability algebras III: some examples',
#  'Subset Codes for Packet Networks',
#  'Finding Efficient Region in The Plane with Line segments',
#  'Randomness and Non-determinism',
#  'Sharp Bounds on Random Walk Eigenvalues via Spectral Embedding',
#  'A Simple Algorithm for Computing BOCP',
#  'Differential Privacy for the Analyst via Private Equilibrium Computation',
#  'Strong Bounds for Evolution in Undirected Graphs',
#  'Recognizing Interval Bigraphs by Forbidden Patterns',
#  'Computational topology and normal surfaces: Theoretical and experimental\n  complexity bounds',
#  'Confusion of Tagged Perturbations in Forward Automatic Differentiation\n  of Higher-Order Functions',
#  'Blind Deconvolution using Convex Programming',
#  'Circuit complexity and Problem structure in Hamming space',
#  'Using Isabelle to verify special relativity, with application to\n  hypercomputation theory',
#  'A new class of SETI beacons that contain information (22-aug-2010)',
#  'The projector algorithm: a simple parallel algorithm for computing\n  Voronoi diagrams and Delaunay graphs',
#  'Threshold Digraphs',
#  'The information and its observer: external and internal information\n  processes, information cooperation, and the origin of the observer intellect',
#  "Computably Categorical Fields via Fermat's Last Theorem",
#  'On two conjectures of Maurer concerning basis graphs of matroids',
#  'On online energy harvesting in multiple access communication systems',
#  'Direct QR factorizations for tall-and-skinny matrices in MapReduce\n  architectures',
#  'Spectral Condition-Number Estimation of Large Sparse Matrices',
#  'Artificial Intelligence Framework for Simulating Clinical\n  Decision-Making: A Markov Decision Process Approach',
#  'New elements for a network (including brain) general theory during\n  learning period',
#  'Feature Learning in Deep Neural Networks - Studies on Speech Recognition\n  Tasks',
#  'Nested Recursions, Simultaneous Parameters and Tree Superpositions',
#  'Approximately counting semismooth integers',
#  'On Gaussian Half-Duplex Relay Networks',
#  'The Capacity of Adaptive Group Testing',
#  'Quantum Lyapunov Control Based on the Average Value of an Imaginary\n  Mechanical Quantity',
#  'Expressing Second-order Sentences in Intuitionistic Dependence Logic',
#  'Target Estimation in Colocated MIMO Radar via Matrix Completion',
#  'Verifying the Consistency of Remote Untrusted Services with\n  Conflict-Free Operations',
#  'Achieving AWGN Channel Capacity With Lattice Gaussian Coding',
#  'A Note on "A polynomial-time algorithm for global value numbering"',
#  'Diagonalizing by Fixed-Points',
#  'Injectivity w.r.t. Distribution of Elements in the Compressed Sequences\n  Derived from Primitive Sequences over $Z/p^eZ$',
#  'Mining Representative Unsubstituted Graph Patterns Using Prior\n  Similarity Matrix',
#  'On the Entropy of Couplings',
#  'Network Detection Theory and Performance',
#  'Interference alignment for the MIMO interference channel',
#  'Parameterized Complexity of Discrete Morse Theory',
#  'Structures Without Scattered-Automatic Presentation',
#  'Stable and Informative Spectral Signatures for Graph Matching',
#  'Simulating the Smart Grid',
#  'Asymptotic Behaviour and Ratios of Complexity in Cellular Automata',
#  'Smart Microgrids: Overview and Outlook',
#  'Newton-Based Optimization for Kullback-Leibler Nonnegative Tensor\n  Factorizations',
#  'Parameterized Complexity of 1-Planarity',
#  'Selling Multiple Correlated Goods: Revenue Maximization and Menu-Size\n  Complexity (old title: "The Menu-Size Complexity of Auctions")',
#  'Strongly light subgraphs in the 1-planar graphs with minimum degree 7',
#  'The Ergodic Capacity of the Multiple Access Channel Under Distributed\n  Scheduling - Order Optimality of Linear Receivers',
#  'Multi-Sided Boundary Labeling',
#  'Disappointment in Social Choice Protocols',
#  'Computing Solution Operators of Boundary-value Problems for Some Linear\n  Hyperbolic Systems of PDEs',
#  'Enabling Self-Powered Autonomous Wireless Sensors with New-Generation\n  I2C-RFID Chips',
#  'The Query Complexity of Correlated Equilibria',
#  'Finite-Length and Asymptotic Analysis of Correlogram for Undersampled\n  Data',
#  'What is Visualization Really for?',
#  'Certifying Machine Code Safe from Hardware Aliasing: RISC is not\n  necessarily risky',
#  'Studying new classes of graph metrics',
#  'Mashup of Meta-Languages and its Implementation in the Kermeta Language\n  Workbench',
#  'A Graphical Transformation for Belief Propagation: Maximum Weight\n  Matchings and Odd-Sized Cycles',
#  'Layered Separators in Minor-Closed Graph Classes with Applications',
#  "A Systematically Empirical Evaluation of Vulnerability Discovery Models:\n  a Study on Browsers' Vulnerabilities",
#  'Capacity Scaling in MIMO Systems with General Unitarily Invariant Random\n  Matrices',
#  'arXiv e-prints and the journal of record: An analysis of roles and\n  relationships',
#  'Automatic functions, linear time and learning',
#  'Roughening Methods to Prevent Sample Impoverishment in the Particle PHD\n  Filter',
#  'Efficient Two-Stage Group Testing Algorithms for Genetic Screening',
#  'Low-Density Parity-Check Codes From Transversal Designs With Improved\n  Stopping Set Distributions',
#  'Soundness and Completeness of the NRB Verification Logic',
#  'On the Resilience of Bipartite Networks',
#  'Broadcasting in Ad Hoc Multiple Access Channels',
#  'Harmony Perception by Periodicity Detection',
#  'An Empirical Study into Annotator Agreement, Ground Truth Estimation,\n  and Algorithm Evaluation',
#  'Arising information regularities in an observer',
#  'Periodic Strategies: A New Solution Concept and an Algorithm for\n  NonTrivial Strategic Form Games',
#  'General Drift Analysis with Tail Bounds',
#  'Coping with Unreliable Workers in Internet-based Computing: An\n  Evaluation of Reputation Mechanisms',
#  'Introduction to Queueing Theory and Stochastic Teletraffic Models',
#  'Perfect Codes in the Discrete Simplex',
#  'Distributed Bayesian Detection with Byzantine Data',
#  'Empirical Evidence of Large-Scale Diversity in API Usage of\n  Object-Oriented Software',
#  'Near Linear Time Approximation Schemes for Uncapacitated and Capacitated\n  b--Matching Problems in Nonbipartite Graphs',
#  'On Lower Complexity Bounds for Large-Scale Smooth Convex Optimization',
#  'Sparse Reconstruction-based Detection of Spatial Dimension Holes in\n  Cognitive Radio Networks',
#  'Convex recovery from interferometric measurements',
#  'A Comprehensive Evaluation of Machine Learning Techniques for Cancer\n  Class Prediction Based on Microarray Data',
#  'Correcting Grain-Errors in Magnetic Media',
#  'Holographic Algorithms Beyond Matchgates',
#  'The Power of Localization for Efficiently Learning Linear Separators\n  with Noise',
#  'A note on T\\"uring\'s 1936',
#  'Dynamic Approximate All-Pairs Shortest Paths: Breaking the O(mn) Barrier\n  and Derandomization',
#  'Spectral Sequences, Exact Couples and Persistent Homology of filtrations',
#  'Low-Dimensional Reconciliation for Continuous-Variable Quantum Key\n  Distribution',
#  'A Note on Topology Preservation in Classification, and the Construction\n  of a Universal Neuron Grid',
#  'Cop and robber game and hyperbolicity',
#  'Full-Diversity Space-Time Block Codes for Integer-Forcing Linear\n  Receivers',
#  'Adaptive matching pursuit for off-grid compressed sensing',
#  'Compressive Multiplexing of Correlated Signals',
#  "Adversarial hypothesis testing and a quantum Stein's Lemma for\n  restricted measurements",
#  'BayesOpt: A Library for Bayesian optimization with Robotics Applications',
#  'An Overview of Nominal-Typing versus Structural-Typing in OOP',
#  'Hypercontractivity of spherical averages in Hamming space',
#  'Local Support Vector Machines:Formulation and Analysis',
#  'New and simple algorithms for stable flow problems',
#  'Automatically Extracting Instances of Code Change Patterns with AST\n  Analysis',
#  'Approximation of smallest linear tree grammar',
#  'Conditioning of Random Block Subdictionaries with Applications to\n  Block-Sparse Recovery and Regression',
#  'Integrating Communications and Merging Messaging via the eXtensible\n  Messaging and Presence Protocol',
#  'Adversarial Multiple Access Channels with Individual Injection Rates',
#  'Inverse Covariance Estimation for High-Dimensional Data in Linear Time\n  and Space: Spectral Methods for Riccati and Sparse Models',
#  'Inclusion-exclusion enhanced by nerve stimulation',
#  'Countering Wrapping Attack on XML Signature in SOAP Message for Cloud\n  Computing',
#  'Flips in combinatorial pointed pseudo-triangulations with face degree at\n  most four',
#  'Learning ambiguous functions by neural networks',
#  'Physical-Layer Cryptography Through Massive MIMO',
#  'The asymptotic $k$-SAT threshold',
#  'Spectra of random networks in the weak clustering regime',
#  "Moser's Shadow Problem",
#  'An Improved Majority-Logic Decoder Offering Massively Parallel Decoding\n  for Real-Time Control in Embedded Systems',
#  'Sparsity-Promoting Sensor Selection for Non-linear Measurement Models',
#  'On Jacobian group arithmetic for typical divisors on curves',
#  'Some Remarks on Lower Bounds for Queue Machines (Preliminary Report)',
#  'Guaranteed Collision Detection With Toleranced Motions',
#  'Easy Accurate Reading and Writing of Floating-Point Numbers',
#  'An Improved Solution for Restricted and Uncertain TRQ',
#  'Bidding Games and Efficient Allocations',
#  'Zero-Error Capacity of a Class of Timing Channels',
#  'Private Matchings and Allocations',
#  'Coordinated Tethering for Multi-RAT Cellular Networks: An Algorithmic\n  Solution and Performance Analysis',
#  'Fingerprinting Codes and the Price of Approximate Differential Privacy',
#  'Mining Software Repair Models for Reasoning on the Search Space of\n  Automated Program Fixing',
#  'A parallel directional Fast Multipole Method',
#  'Notions of Symmetry for Finite Strategic-Form Games',
#  'On the Complexity of Random Satisfiability Problems with Planted\n  Solutions',
#  'An energy function and its application to the periodic behavior of\n  k-reversible processes',
#  'Want a Good Answer? Ask a Good Question First!',
#  'One-Class Classification: Taxonomy of Study and Review of Techniques',
#  'On Optimal Disc Covers and a New Characterization of the Steiner Center',
#  'Abmash: Mashing Up Legacy Web Applications by Automated Imitation of\n  Human Actions',
#  'Optimal detection of intersections between convex polyhedra',
#  'Bandits and Experts in Metric Spaces',
#  'Instruction sequences expressing multiplication algorithms',
#  'Outerstring graphs are $\\chi$-bounded',
#  'Simplicial Homology for Future Cellular Networks',
#  'The False Premises and Promises of Bitcoin',
#  'On two Algorithmic Problems about Synchronizing Automata',
#  'Silent error detection in numerical time-stepping schemes',
#  'Multiple Access Multicarrier Continuous-Variable Quantum Key\n  Distribution',
#  'On Eavesdropper-Tolerance Capability of Two-Hop Wireless Networks',
#  'The Symmetric Convex Ordering: A Novel Partial Order for B-DMCs Ordering\n  the Information Sets of Polar Codes',
#  'On the genericity of Whitehead minimality',
#  'The Micro Dynamics of Collective Violence',
#  'Learning optimization models in the presence of unknown relations',
#  'Efficient random sampling of binary and unary-binary trees via holonomic\n  equations',
#  'Time series forecasting using neural networks',
#  'Distributed Energy Efficient Channel Allocation',
#  'Empirical Patterns in Google Scholar Citation Counts',
#  'Clustering, Coding, and the Concept of Similarity',
#  'Bits Through Bufferless Queues',
#  'Group Testing with Prior Statistics',
#  'Towards a Uniform Theory of Effectful State Machines',
#  'Advanced Signal Processing Techniqes to Study Normal and Epileptic EEG',
#  'Predicate Logic as a Modelling Language: The IDP System',
#  'On giant components and treewidth in the layers model',
#  'Motion planning and control of a planar polygonal linkage',
#  'On the Properties of the Priority Deriving Procedure in the Pairwise\n  Comparisons Method',
#  'Local algorithms for independent sets are half-optimal',
#  'Dual Query: Practical Private Query Release for High Dimensional Data',
#  'Generalized Signal Alignment For MIMO Two-Way X Relay Channels',
#  'In silico Proteome Cleavage Reveals Iterative Digestion Strategy for\n  High Sequence Coverage',
#  'Leveraging Long-Term Predictions and Online-Learning in Agent-based\n  Multiple Person Tracking',
#  'Rendezvous in Networks in Spite of Delay Faults',
#  'Information-Geometric Equivalence of Transportation Polytopes',
#  'On the Convergence of Approximate Message Passing with Arbitrary\n  Matrices',
#  'Differential Privacy: An Economic Method for Choosing Epsilon',
#  'Indian Buffet Process Deep Generative Models for Semi-Supervised\n  Classification',
#  'Privately Solving Linear Programs',
#  'A reclaimer scheduling problem arising in coal stockyard management',
#  'Unification and Logarithmic Space',
#  "Proof Complexity and the Kneser-Lov\\'asz Theorem",
#  'Densely Entangled Financial Systems',
#  'From Predictive to Prescriptive Analytics',
#  'The Anatomy of a Modular System for Media Content Analysis',
#  'Learning multifractal structure in large networks',
#  'Scalable methods for nonnegative matrix factorizations of near-separable\n  tall-and-skinny matrices',
#  'Percolation with small clusters on random graphs',
#  'A search for quantum coin-flipping protocols using optimization\n  techniques',
#  'Clique counting in MapReduce: theory and experiments',
#  'New Ideas for Brain Modelling',
#  'Automated analysis of security protocols with global state',
#  'Optimal Patching in Clustered Malware Epidemics',
#  'Optimal Energy-Aware Epidemic Routing in DTNs',
#  'Optimal ancilla-free Clifford+T approximation of z-rotations',
#  'Study of Behaviours via Visitable Paths',
#  'P is not equal to NP by Modus Tollens',
#  'Occam Bound on Lowest Complexity of Elements',
#  "Complete simultaneous conjugacy invariants in Artin's braid groups",
#  'Improved Approximation Algorithms for Box Contact Representations',
#  'Parameter Estimation of Social Forces in Crowd Dynamics Models via a\n  Probabilistic Method',
#  'Disaster Recovery in Wireless Networks: A Homology-Based Algorithm',
#  'Mining Attribute-Based Access Control Policies from Logs',
#  'Do the Fix Ingredients Already Exist? An Empirical Inquiry into the\n  Redundancy Assumptions of Program Repair Approaches',
#  'Spectral concentration and greedy k-clustering',
#  'Sublinear algorithms for local graph centrality estimation',
#  'Duality and Optimality of Auctions for Uniform Distributions',
#  'r-Extreme Signalling for Congestion Control',
#  'Infinite dimensional finitely forcible graphon',
#  'Principles of Antifragile Software',
#  'Automatic Repair of Buggy If Conditions and Missing Preconditions with\n  SMT',
#  'Generating Synchronizing Automata with Large Reset Lengths',
#  'Near-optimal sample compression for nearest neighbors',
#  'Optimal versus Nash Equilibrium Computation for Networked Resource\n  Allocation',
#  'Optimal Power Flow as a Polynomial Optimization Problem',
#  'Using Covert Topological Information for Defense Against Malicious\n  Attacks on DC State Estimation',
#  'Quantum Attacks on Classical Proof Systems - The Hardness of Quantum\n  Rewinding',
#  'Tight Bounds for Restricted Grid Scheduling',
#  'Coding Theoretic Construction of Quantum Ramp Secret Sharing',
#  'Crux: Locality-Preserving Distributed Services',
#  'Further result on acyclic chromatic index of planar graphs',
#  'Generalized Signal Alignment: On the Achievable DoF for Multi-User MIMO\n  Two-Way Relay Channels',
#  'Unguarded Recursion on Coinductive Resumptions',
#  'Some undecidability results for asynchronous transducers and the\n  Brin-Thompson group 2V',
#  'Graphical potential games',
#  'Leader-following Consensus of Multi-agent Systems over Finite Fields',
#  'Policy Gradients for CVaR-Constrained MDPs',
#  'AND-compression of NP-complete problems: Streamlined proof and minor\n  observations',
#  'Signal-noise search RMT estimator with adaptive decision criterion for\n  estimating the number of signals based on random matrix theory',
#  'Efficient Evaluation of the Probability Density Function of a Wrapped\n  Normal Distribution',
#  'A Datalog-based Computational Model for Coordination-free, Data-Parallel\n  Systems',
#  'A Stable Marriage Requires Communication',
#  'The "Runs" Theorem',
#  "A faster method for computing Gama-Nguyen-Regev's extreme pruning\n  coefficients",
#  'Extensions of Configuration Structures',
#  'Scaling limits and influence of the seed graph in preferential\n  attachment trees',
#  'Distinct Distances: Open Problems and Current Bounds',
#  "Load Hiding of Household's Power Demand",
#  'Structural Sparsity of Complex Networks: Bounded Expansion in Random\n  Models and Real-World Graphs',
#  'Lower Bounds for Tropical Circuits and Dynamic Programs',
#  "Consistency of Quine's New Foundations using nominal techniques",
#  'The number system hidden inside the Boolean satisfiability problem',
#  'Information, Meaning, and Intellectual Organization in Networks of\n  Inter-Human Communication',
#  'The Moser-Tardos Framework with Partial Resampling',
#  'Fast, Robust and Non-convex Subspace Recovery',
#  'Strongly stable ideals and Hilbert polynomials',
#  'How to Achieve the Capacity of Asymmetric Channels',
#  'A Bayes consistent 1-NN classifier',
#  'Geometrical Localization Algorithm for 3-D Wireless Sensor Networks',
#  'Synchronization of finite-state pulse-coupled oscillators',
#  'Planar Graphs: Random Walks and Bipartiteness Testing',
#  'Discovery of Important Crossroads in Road Network using Massive Taxi\n  Trajectories',
#  'An improved analysis of the M\\"omke-Svensson algorithm for graph-TSP on\n  subquartic graphs',
#  'Proving differential privacy in Hoare logic',
#  'Optimal Spectrum Management in Two-User Interference Channels',
#  'Perfect sampling algorithm for Schur processes',
#  'A Generalized Write Channel Model for Bit-Patterned Media Recording',
#  'Minors and dimension',
#  'Toward Selectivity Based Keyword Extraction for Croatian News',
#  'Sparse Partially Linear Additive Models',
#  'Integrating R and Hadoop for Big Data Analysis',
#  'Implementing Transitive Credit with JSON-LD',
#  'Abstractions, Algorithms and Data Structures for Structural\n  Bioinformatics in PyCogent',
#  "Acyclic Edge Coloring through the Lov\\'asz Local Lemma",
#  'Multichannel Compressive Sensing MRI Using Noiselet Encoding',
#  'Optimization Techniques on Riemannian Manifolds',
#  'A Genetic Algorithm for Software Design Migration from Structured to\n  Object Oriented Paradigm',
#  'Multiplicative Complexity of Vector Valued Boolean Functions',
#  'Higher-Order Approximate Relational Refinement Types for Mechanism\n  Design and Differential Privacy',
#  'Isomorphism within Naive Type Theory',
#  'A note on multipivot Quicksort',
#  'New data, new possibilities: Exploring the insides of Altmetric.com',
#  'Precision of Pulse-Coupled Oscillator Synchronization on FPGA-Based\n  Radios',
#  'Polynomial size linear programs for problems in P',
#  'Multilayer bootstrap networks',
#  'A special role of Boolean quadratic polytopes among other combinatorial\n  polytopes',
#  'Stable Throughput Region of Cognitive-Relay Networks with Imperfect\n  Sensing and Finite Relaying Buffer',
#  'Spoke-Darts for High-Dimensional Blue-Noise Sampling',
#  'On optimal approximability results for computing the strong metric\n  dimension',
#  'On the structure of classical realizability models of ZF',
#  'Near-Constant-Time Distributed Algorithms on a Congested Clique',
#  'Matrix Completion under Interval Uncertainty',
#  'Distributed Graph Automata and Verification of Distributed Algorithms',
#  'On the neighbour sum distinguishing index of planar graphs',
#  'An algorithm for canonical forms of finite subsets of $\\mathbb{Z}^d$ up\n  to affinities',
#  'Parallel generator of $q$-valued pseudorandom sequences based on\n  arithmetic polynomials',
#  'Treewidth of graphs with balanced separations',
#  'FESTUNG: A MATLAB / GNU Octave toolbox for the discontinuous Galerkin\n  method. Part I: Diffusion operator',
#  'Static Analysis for Extracting Permission Checks of a Large Scale\n  Framework: The Challenges And Solutions for Analyzing Android',
#  'Laplace Functional Ordering of Point Processes in Large-scale Wireless\n  Networks',
#  'Crossing Minimization for 1-page and 2-page Drawings of Graphs with\n  Bounded Treewidth',
#  'Flat Foldings of Plane Graphs with Prescribed Angles and Edge Lengths',
#  'GPGPU Computing',
#  'Nash Equilbria for Quadratic Voting',
#  'Polynomial solvability of $NP$-complete problems',
#  'Evaluation of Position-related Information in Multipath Components for\n  Indoor Positioning',
#  'A level set based method for fixing overhangs in 3D printing',
#  'An Epistemic Strategy Logic',
#  'Secure pseudo-random linear binary sequences generators based on\n  arithmetic polynoms',
#  'A simple proof of the completeness of APAL',
#  'A Framework for Practical Parallel Fast Matrix Multiplication',
#  'Test Case Purification for Improving Fault Localization',
#  'Strong converse exponent for classical-quantum channel coding',
#  'Select with Small Groups',
#  'MIMO-MC Radar: A MIMO Radar Approach Based on Matrix Completion',
#  'Stable Cosparse Recovery via \\ell_p-analysis Optimization',
#  'Doing-it-All with Bounded Work and Communication',
#  'A Benchmark Suite for Template Detection and Content Extraction',
#  'Estimating topological properties of weighted networks from limited\n  information',
#  'Impossibility of Classically Simulating One-Clean-Qubit Computation',
#  'Field evidence of social influence in the expression of political\n  preferences: the case of secessionist flags in Barcelona',
#  'A New DoF Upper Bound and Its Achievability for $K$-User MIMO Y Channels',
#  'RENOIR - A Dataset for Real Low-Light Image Noise Reduction',
#  'Non-myopic learning in repeated stochastic games',
#  'Interference Functionals in Poisson Networks',
#  'Identification of Dynamic functional brain network states Through Tensor\n  Decomposition',
#  'HD-CNN: Hierarchical Deep Convolutional Neural Network for Large Scale\n  Visual Recognition',
#  'Entropy NAND: Early Functional Completeness in Entropy Networks',
#  'Spatial Straight Line Linkages by Factorization of Motion Polynomials',
#  'An easy subexponential bound for online chain partitioning',
#  'Ricci Curvature and the Manifold Learning Problem',
#  'A lazy approach to on-line bipartite matching',
#  'Selection-based Approach to Cooperative Interval Games',
#  'Decoupling Multivariate Polynomials Using First-Order Information',
#  'Numerical Optimization for Symmetric Tensor Decomposition',
#  'A Cut Principle for Information Flow',
#  'An Algebra of Reversible Computation',
#  'Active Regression by Stratification',
#  'Coalition Structure Generation on Graphs',
#  'Complexity of LP in Terms of the Face Lattice',
#  'Dynamic Analysis of Digital Chaotic Maps via State-Mapping Networks',
#  'On the Inequalities of Projected Volumes and the Constructible Region',
#  'Construction of Capacity-Achieving Lattice Codes: Polar Lattices',
#  'Modelling serendipity in a computational context',
#  'Jointly Private Convex Programming',
#  'Nearly Linear-Time Packing and Covering LP Solvers',
#  'Eigenvectors of Orthogonally Decomposable Functions',
#  'Playing the Wrong Game: Bounding Externalities in Diverse Populations of\n  Agents',
#  'Beta-expansions of rational numbers in quadratic Pisot bases',
#  'Computational Complexity of Functions',
#  'Social media fingerprints of unemployment',
#  'Growing Scale-free Networks by a Mediation-Driven Attachment Rule',
#  'Derandomized Graph Product Results using the Low Degree Long Code',
#  'A Game Theoretic Model for the Formation of Navigable Small-World\n  Networks --- the Tradeoff between Distance and Reciprocity',
#  'Scalable Wake-up of Multi-Channel Single-Hop Radio Networks',
#  'Security Analysis of the Unrestricted Identity-Based Aggregate Signature\n  Scheme',
#  'Automated Reasoning in Deontic Logic',
#  'Dual-induced multifractality in online viewing activity',
#  'Deterministic Edge Connectivity in Near-Linear Time',
#  'Subtyping in Java is a Fractal',
#  'Minimization of Transformed $L_1$ Penalty: Theory, Difference of Convex\n  Function Algorithm, and Robust Application in Compressed Sensing',
#  'Salient Object Detection: A Survey',
#  'Mesoscopic analysis of online social networks - The role of negative\n  ties',
#  'Efficient storage of Pareto points in biobjective mixed integer\n  programming',
#  'Spatiotemporal Modeling of a Pervasive Game',
#  'Discrete Sampling: A graph theoretic approach to Orthogonal\n  Interpolation',
#  'Consistency proof of a fragment of PV with substitution in bounded\n  arithmetic',
#  'A Chasm Between Identity and Equivalence Testing with Conditional\n  Queries',
#  'Semidefinite Programming Approach to Gaussian Sequential Rate-Distortion\n  Trade-offs',
#  'Influence of sociodemographic characteristics on human mobility',
#  'Bits from Biology for Computational Intelligence',
#  "Approximate MAP Estimation for Pairwise Potentials via Baker's Technique",
#  'Krylov Subspace Methods in Dynamical Sampling',
#  'Efficient algorithms to decide tightness',
#  'Convolutional codes from unit schemes',
#  'Integer-Programming Ensemble of Temporal-Relations Classifiers',
#  'Chases and Escapes, and Optimization Problems',
#  'Generalized Singular Value Thresholding',
#  'Exploiting Packing Components in General-Purpose Integer Programming\n  Solvers',
#  'HyperSpectral classification with adaptively weighted L1-norm\n  regularization and spatial postprocessing',
#  'Autonomous Load Disaggregation Approach based on Active Power\n  Measurements',
#  "Computational Aspects of the Colorful Carath\\'eodory Theorem",
#  'How Much Lookahead is Needed to Win Infinite Games?',
#  'Dynamics of Information Diffusion and Social Sensing',
#  'An Ordinal Minimax Theorem',
#  'Generalized Vietoris Bisimulations',
#  'How many queries are needed to distinguish a truncated random\n  permutation from a random function?',
#  'Maximal Correlation Secrecy',
#  'Enumerative Coding for Line Polar Grassmannians with applications to\n  codes',
#  'The Timestamp of Timed Automata',
#  'Revisiting Non-Progressive Influence Models: Scalable Influence\n  Maximization',
#  'Deducing Truth from Correlation',
#  'Nearest Descent, In-Tree, and Clustering',
#  'Finding 2-Edge and 2-Vertex Strongly Connected Components in Quadratic\n  Time',
#  'Deep metric learning using Triplet network',
#  'New results on classical and quantum counter automata',
#  'Learning the nonlinear geometry of high-dimensional data: Models and\n  algorithms',
#  'Rational Groupthink',
#  'Sub-linear Time Support Recovery for Compressed Sensing using\n  Sparse-Graph Codes',
#  'Automatic Photo Adjustment Using Deep Neural Networks',
#  'Cloud K-SVD: A Collaborative Dictionary Learning Algorithm for Big,\n  Distributed Data',
#  'Propositional Logics of Dependence',
#  'A Constructive Proof on the Compositionality of Linearizability',
#  'Odd graph and its applications to the strong edge coloring',
#  'Maze Solving Automatons for Self-Healing of Open Interconnects: Modular\n  Add-on for Circuit Boards',
#  'On the Uniform Computational Content of Computability Theory',
#  'Characterizing the Google Books corpus: Strong limits to inferences of\n  socio-cultural and linguistic evolution',
#  'Augur: a decentralized oracle and prediction market platform',
#  'Salient Object Detection: A Benchmark',
#  'Functionals and hardware',
#  'Dirichlet Process Parsimonious Mixtures for clustering',
#  'The Dead Cryptographers Society Problem',
#  'Categorified Reeb Graphs',
#  'Clustering based on the In-tree Graph Structure and Affinity Propagation',
#  'Algorithms for Scheduling Malleable Cloud Tasks',
#  'A Novel Implementation of QuickHull Algorithm on the GPU',
#  'Subtropical Real Root Finding',
#  'Better Answers to Real Questions',
#  'Recursive Bayesian Filtering in Circular State Spaces',
#  'An Algebra of Reversible Quantum Computing',
#  'A speed and departure time optimization algorithm for the\n  Pollution-Routing Problem',
#  'Fourier Analysis of MAC Polarization',
#  'Geodesic convolutional neural networks on Riemannian manifolds',
#  'Compressive Sampling of Ensembles of Correlated Signals',
#  'Implementation of an Automatic Syllabic Division Algorithm from Speech\n  Files in Portuguese Language',
#  'Efficient Divide-And-Conquer Classification Based on Feature-Space\n  Decomposition',
#  'Simple Mechanisms for a Subadditive Buyer and Applications to Revenue\n  Monotonicity',
#  'Bar recursion in classical realisability : dependent choice and\n  continuum hypothesis',
#  'Reversibility of d-State Finite Cellular Automata',
#  'On the Lexical Distinguishability of Source Code',
#  'Code generator matrices as RNG conditioners',
#  'A Matrix Laurent Series-based Fast Fourier Transform for Blocklengths\n  N=4 (mod 8)',
#  'Lower Bounds for Monotone Counting Circuits',
#  'Data Bits in Karnaugh Map and Increasing Map Capability in Error\n  Correcting',
#  'Rigorous Deductive Argumentation for Socially Relevant Issues',
#  'MATLAB based language for generating randomized multiple choice\n  questions',
#  'Dynamic DFS Tree in Undirected Graphs: breaking the $O(m)$ barrier',
#  'Measurement Scale Effect on Prediction of Soil Water Retention Curve and\n  Saturated Hydraulic Conductivity',
#  'Fast integer multiplication using generalized Fermat primes',
#  'Fast event-based epidemiological simulations on national scales',
#  'Contextuality, Cohomology and Paradox',
#  'The Z Transform over Finite Fields',
#  'A Full Frequency Masking Vocoder for Legal Eavesdropping Conversation\n  Recording',
#  'Varieties',
#  'Computer-aided verification in mechanism design',
#  'Bayesian Incentive-Compatible Bandit Exploration',
#  'Temporal Network Optimization Subject to Connectivity Constraints',
#  'The exp-log normal form of types',
#  'Tensor Spectral Clustering for Partitioning Higher-order Network\n  Structures',
#  'Practically-Self-Stabilizing Virtual Synchrony',
#  'On the Effects of Low-Quality Training Data on Information Extraction\n  from Clinical Reports',
#  'Optimizing Text Quantifiers for Multivariate Loss Functions',
#  'On asymptotically good ramp secret sharing schemes',
#  'Capturing k-ary Existential Second Order Logic with k-ary\n  Inclusion-Exclusion Logic',
#  'Automatic differentiation in machine learning: a survey',
#  'A Flexible Implementation of a Matrix Laurent Series-Based 16-Point Fast\n  Fourier and Hartley Transforms',
#  'Rectified Factor Networks',
#  'Minimal Distance of Propositional Models',
#  'Exploiting Feature and Class Relationships in Video Categorization with\n  Regularized Deep Neural Networks',
#  'Highly corrupted image inpainting through hypoelliptic diffusion',
#  'Cluster Synchronization of Coupled Systems with Nonidentical Linear\n  Dynamics',
#  'Characterising Modal Definability of Team-Based Logics via the Universal\n  Modality',
#  'Tropical differential equations',
#  'Knowledge-aided Two-dimensional Autofocus for Spotlight SAR Polar Format\n  Imagery',
#  '23-bit Metaknowledge Template Towards Big Data Knowledge Discovery and\n  Management',
#  'Novel Metaknowledge-based Processing Technique for Multimedia Big Data\n  clustering challenges',
#  'Utility-Theoretic Ranking for Semi-Automated Text Classification',
#  'Approximation Algorithms for Computing Maximin Share Allocations',
#  'Joint Active Learning with Feature Selection via CUR Matrix\n  Decomposition',
#  'Faster quantum mixing for slowly evolving sequences of Markov chains',
#  'Complete intersection vanishing ideals on sets of clutter type over\n  finite fields',
#  'Minimal classes of graphs of unbounded clique-width defined by finitely\n  many forbidden induced subgraphs',
#  'Higher Weights of Affine Grassmann Codes and Their Duals',
#  'New Algorithms for Computing a Single Component of the Discrete Fourier\n  Transform',
#  'Mean Field Games in Nudge Systems for Societal Networks',
#  'SybilFrame: A Defense-in-Depth Framework for Structure-Based Sybil\n  Detection',
#  'Dynamic Partitioning of Physical Memory Among Virtual Machines,\n  ASMI:Architectural Support for Memory Isolation',
#  'Testing Randomness by Matching Pennies',
#  'An improved return-mapping scheme for nonsmooth yield surfaces: PART I -\n  the Haigh-Westergaard coordinates',
#  'Algorithms and complexity for Turaev-Viro invariants',
#  'Bridging Social Media via Distant Supervision',
#  'A Residual Based Sparse Approximate Inverse Preconditioning Procedure\n  for Large Sparse Linear Systems',
#  'Really Natural Linear Indexed Type Checking',
#  'IMP with exceptions over decorated logic',
#  'Cost-Effective Conceptual Design Using Taxonomies',
#  'Polynomial complexity recognizing a tropical linear variety',
#  'Construction of FuzzyFind Dictionary using Golay Coding Transformation\n  for Searching Applications',
#  'Tree spanners of bounded degree graphs',
#  'Large-scale Biological Meta-database Management',
#  'Global Bandits',
#  'Towards Easier and Faster Sequence Labeling for Natural Language\n  Processing: A Search-based Probabilistic Online Learning Framework (SAPO)',
#  'Geometry of Interaction for MALL via Hughes-vanGlabbeek Proof-Nets',
#  'Complete Simulation of Automata Networks',
#  'On the Exact and Approximate Eigenvalue Distribution for Sum of Wishart\n  Matrices',
#  'Exploring the complex pattern of information spreading in online blog\n  communities',
#  'On the Total-Power Capacity of Regular-LDPC Codes with Iterative\n  Message-Passing Decoders',
#  'The Effect of Recency to Human Mobility',
#  'Reactive Synthesis Without Regret',
#  'Copyless Cost-Register Automata: Structure, Expressiveness, and Closure\n  Properties',
#  'Profit Maximization for Geographical Dispersed Green Data Centers',
#  'Detecting Falls with X-Factor Hidden Markov Models',
#  'A Survey on Privacy and Security in Online Social Networks',
#  'Sparse multivariate polynomial interpolation in the basis of Schubert\n  polynomials',
#  'Extended Formulations for Independence Polytopes of Regular Matroids',
#  'Optimal Hierarchical Radio Resource Management for HetNets with Flexible\n  Backhaul',
#  'The Parametric Closure Problem',
#  'Quantum and classical coin-flipping protocols based on bit-commitment\n  and their point games',
#  'Information Hiding as a Challenge for Malware Detection',
#  'Equitable total coloring of corona of cubic graphs',
#  'Semantic Enrichment of Mobile Phone Data Records Using Background\n  Knowledge',
#  "Stability of Stochastic Approximations with `Controlled Markov' Noise\n  and Temporal Difference Learning",
#  'Acyclic chromatic index of triangle-free 1-planar graphs',
#  'The Fallacy of Favoring Gradual Replacement Mind Uploading Over\n  Scan-and-Copy',
#  'Sampling Correctors',
#  'Approximate Fitting of a Circular Arc When Two Points Are Known',
#  'Searching for a Compressed Polyline with a Minimum Number of Vertices',
#  'High Speed Hashing for Integers and Strings',
#  'Obstructions for three-coloring graphs without induced paths on six\n  vertices',
#  'A Deterministic Almost-Tight Distributed Algorithm for Approximating\n  Single-Source Shortest Paths',
#  'A multi-class approach for ranking graph nodes: models and experiments\n  with incomplete data',
#  'Sublinear-Time Decremental Algorithms for Single-Source Reachability and\n  Shortest Paths on Directed Graphs',
#  'Average Convergence Rate of Evolutionary Algorithms',
#  'Theory of Optimizing Pseudolinear Performance Measures: Application to\n  F-measure',
#  'Block Basis Factorization for Scalable Kernel Matrix Evaluation',
#  'Colocated MIMO Radar Waveform Design for Transmit Beampattern Formation',
#  'On the Rigidity of Sparse Random Graphs',
#  'Multi-Target Tracking in Distributed Sensor Networks using Particle PHD\n  Filters',
#  'Weihrauch-completeness for layerwise computability',
#  'Measuring dependence powerfully and equitably',
#  'An Empirical Study of Leading Measures of Dependence',
#  'The Topology of Biological Networks from a Complexity Perspective',
#  'How Far Can You Get By Combining Change Detection Algorithms?',
#  'Detecting the large entries of a sparse covariance matrix in\n  sub-quadratic time',
#  'Timed Consistent Network Updates',
#  'Pinball Loss Minimization for One-bit Compressive Sensing: Convex Models\n  and Algorithms',
#  'Robust Biomolecular Finite Automata',
#  'Automatic Facial Expression Recognition Using Features of Salient Facial\n  Patches',
#  'Unified way for computing dynamics of Bose-Einstein condensates and\n  degenerate Fermi gases',
#  'Global Convergence of Unmodified 3-Block ADMM for a Class of Convex\n  Minimization Problems',
#  'Provably Correct Algorithms for Matrix Column Subset Selection with\n  Selectively Sampled Data',
#  'Read Mapping on de Bruijn graph',
#  'Convective regularization for optical flow',
#  'Synthesising Executable Gene Regulatory Networks from Single-cell Gene\n  Expression Data',
#  'A New Oscillating-Error Technique for Classifiers',
#  'Fuzzy Least Squares Twin Support Vector Machines',
#  'Decentralized Sequential Composite Hypothesis Test Based on One-Bit\n  Communication',
#  'VPG and EPG bend-numbers of Halin Graphs',
#  'Polynomially Low Error PCPs with polyloglog n Queries via Modular\n  Composition',
#  'Sketching for Sequential Change-Point Detection',
#  'Coalgebraic Infinite Traces and Kleisli Simulations',
#  'Times series averaging from a probabilistic interpretation of\n  time-elastic kernel',
#  'Revisiting Actor Programming in C++',
#  'Semi-algebraic colorings of complete graphs',
#  'Dimension and cut vertices: an application of Ramsey theory',
#  'Team Performance with Test Scores',
#  'Synapse: Synthetic Application Profiler and Emulator',
#  'Compressing Communication in Distributed Protocols',
#  'Formal Concept Analysis for Knowledge Discovery from Biological Data',
#  'Desirability and the birth of incomplete preferences',
#  'Coordinate Descent Converges Faster with the Gauss-Southwell Rule Than\n  Random Selection',
#  'Calculation of the confidence bounds for the fraction nonconforming of\n  normal populations of measurements in clinical laboratory medicine',
#  'Two-dimensional Decoding Algorithms and Recording Techniques for Bit\n  Patterned Media Feasibility Demonstrations',
#  'Soft Computing Techniques for Change Detection in remotely sensed images\n  : A Review',
#  'Multi-View Factorization Machines',
#  'Signs of universality in the structure of culture',
#  'Information measures and cognitive limits in multilayer navigation',
# ...
#  'COMs: Complexes of Oriented Matroids',
#  'Abstract Gringo',
#  'Robust Monotone Submodular Function Maximization',
#  'A Truth Serum for Large-Scale Evaluations',
#  'The Wiretap Channel with Generalized Feedback: Secure Communication and\n  Key Generation',
#  'Partial resampling to approximate covering integer programs',
#  'Mapping Auto-context Decision Forests to Deep ConvNets for Semantic\n  Segmentation',
#  'Fully-Online Suffix Tree and Directed Acyclic Word Graph Construction\n  for Multiple Texts',
#  'Generalized Twisted Gabidulin Codes',
#  'Mobile Multi-View Object Image Search',
#  'Indexing of CNN Features for Large Scale Image Search',
#  'Low-rank spectral optimization via gauge duality',
#  'Proving the Turing Universality of Oritatami Co-Transcriptional Folding\n  (Full Text)',
#  'Episodic Multi-armed Bandits',
#  'Accelerating R with high performance linear algebra libraries',
#  'Structured Prediction: From Gaussian Perturbations to Linear-Time\n  Principled Algorithms',
#  'Computational complexity of distance edge labeling',
#  'Offline and Online Models of Budget Allocation for Maximizing Influence\n  Spread',
#  'Cascading Power Outages Propagate Locally in an Influence Graph that is\n  not the Actual Grid Topology',
#  'Hypergraph coloring up to condensation',
#  'Defending Against Stealthy Attacks on Multiple Nodes with Limited\n  Resources: A Game-Theoretic Analysis',
#  'Improving Decision Analytics with Deep Learning: The Case of Financial\n  Disclosures',
#  'The Pontryagin Maximum Principle for Nonlinear Infinite Horizon Optimal\n  Control Problems with State Constraints',
#  'Topology Control of wireless sensor network using Quantum Inspired\n  Genetic algorithm',
#  'A Combinatorial Model of Interference in Frequency Hopping Schemes',
#  'Technical Note: Split Algorithm in O(n) for the Capacitated Vehicle\n  Routing Problem',
#  'A generalized Goulden-Jackson cluster method and lattice path\n  enumeration',
#  'Optimized Projections for Compressed Sensing via Direct Mutual Coherence\n  Minimization',
#  'Logic Programming with Macro Connectives',
#  'A New Approach to an Old Problem: The Reconstruction of a Go Game\n  through a Series of Photographs',
#  'Binary Compressive Sensing via Analog Fountain Coding',
#  'No acute tetrahedron is an 8-reptile',
#  'Incorporating User Interaction into Imperative Languages',
#  'A Pessimistic Approximation for the Fisher Information Measure',
#  'REBA: A Refinement-Based Architecture for Knowledge Representation and\n  Reasoning in Robotics',
#  'Algorithmic Aspects of Optimal Channel Coding',
#  'Social Influence in the Concurrent Diffusion of Information and\n  Behaviors in Online Social Networks',
#  'Large scale three-dimensional topology optimisation of heat sinks cooled\n  by natural convection',
#  'Distributed Event-Triggered Control for Asymptotic Synchronization of\n  Dynamical Networks',
#  'Quickest Detection for Changes in Maximal kNN Coherence of Random\n  Matrices',
#  'The backtracking survey propagation algorithm for solving random K-SAT\n  problems',
#  'Variable-mixing parameter quantized kernel robust mixed-norm algorithms\n  for combating impulsive interference',
#  'A representation of antimatroids by Horn rules and its application to\n  educational systems',
#  'Structured Interactive Music Scores',
#  '$n$-permutability and linear Datalog implies symmetric Datalog',
#  'A systematic process for evaluating structured perfect Bayesian\n  equilibria in dynamic games with asymmetric information',
#  'SPF-CellTracker: Tracking multiple cells with strongly-correlated moves\n  using a spatial particle filter',
#  'Cooperative Spectrum Sharing Relaying Protocols With Energy Harvesting\n  Cognitive User',
#  'A dual descent algorithm for node-capacitated multiflow problems and its\n  applications',
#  'Subdifferential-based implicit return-mapping operators in Mohr-Coulomb\n  plasticity',
#  'Automatic Software Diversity in the Light of Test Suites',
#  'A Big Data Analyzer for Large Trace Logs',
#  'Strong Pseudoprimes to Twelve Prime Bases',
#  'Using Inclusion Diagrams as an Alternative to Venn Diagrams to Determine\n  the Validity of Categorical Syllogisms',
#  'Verificarlo: checking floating point accuracy through Monte Carlo\n  Arithmetic',
#  'Optimum Traffic Allocation in Bundled Energy Efficient Ethernet Links',
#  'Inference From Visible Information And Background Knowledge',
#  'Diffusion tensor imaging with deterministic error bounds',
#  "Hofstadter's problem for curious readers",
#  'On the $O_\\beta$-hull of a planar point set',
#  'A Topological Approach to Meta-heuristics: Analytical Results on the BFS\n  vs. DFS Algorithm Selection Problem',
#  'Statistical Inference, Learning and Models in Big Data',
#  'Entropic CLT and phase transition in high-dimensional Wishart matrices',
#  'Relational reasoning via probabilistic coupling',
#  'Local structure can identify and quantify influential global spreaders\n  in large scale social networks',
#  'Solving underdetermined systems with error-correcting codes',
#  'An Impossibility Result for Housing Markets with Fractional Endowments',
#  'Measuring Partial Balance in Signed Networks',
#  'Modeling and interpolation of the ambient magnetic field by Gaussian\n  processes',
#  'Markov modeling of online inter-arrival times',
#  'An FPT 2-Approximation for Tree-Cut Decomposition',
#  'Solving constrained quadratic binary problems via quantum adiabatic\n  evolution',
#  'Supervisor Localization of Discrete-Event Systems under Partial\n  Observation',
#  'Randomised enumeration of small witnesses using a decision oracle',
#  'Automated Synthesis of Distributed Self-Stabilizing Protocols',
#  'New bounds on curve tangencies and orthogonalities',
#  'Product Space Models of Correlation: Between Noise Stability and\n  Additive Combinatorics',
#  'Using Contracted Solution Graphs for Solving Reconfiguration Problems',
#  'Shape Aware Matching of Implicit Surfaces based on Thin Shell Energies',
#  'Universal recovery maps and approximate sufficiency of quantum relative\n  entropy',
#  'Adaptive-Robust Control of a Class of Uncertain Nonlinear Systems\n  Utilizing Time-Delayed Input and Position Feedback',
#  'Pricing Policies for Selling Indivisible Storable Goods to Strategic\n  Consumers',
#  'Deterministic Sparse Suffix Sorting in the Restore Model',
#  'Formal Support for Standardizing Protocols with State',
#  'A (1+epsilon)-Approximation for Makespan Scheduling with Precedence\n  Constraints using LP Hierarchies',
#  'Discriminative Learning of the Prototype Set for Nearest Neighbor\n  Classification',
#  'UB-ANC Drone: A Flexible Airborne Networking and Communications Testbed',
#  "Kempe's Universality Theorem for Rational Space Curves",
#  'On the Min-cost Traveling Salesman Problem with Drone',
#  'A data-dependent weighted LASSO under Poisson noise',
#  'Fixpoint Node Selection Query Languages for Trees',
#  'The "handedness" of language: Directional symmetry breaking of sign\n  usage in words',
#  'Approximate Spectral Clustering: Efficiency and Guarantees',
#  'On the Complexity of Robust PCA and $\\ell_1$-norm Low-Rank Matrix\n  Approximation',
#  'FPT Approximation Schemes for Maximizing Submodular Functions',
#  'Coding Theorem and Converse for Abstract Channels with Time Structure\n  and Memory',
#  'Bishellable drawings of $K_n$',
#  'Routing in Unit Disk Graphs',
#  'Trading Networks with Bilateral Contracts',
#  'Distance-2 MDS codes and latin colorings in the Doob graphs',
#  'DC Decomposition of Nonconvex Polynomials with Algebraic Techniques',
#  'On the codes over the Z_3+vZ_3+v^2Z_3',
#  'Cross-boundary Behavioural Reprogrammability Reveals Evidence of\n  Pervasive Universality',
#  'Balanced Islands in Two Colored Point Sets in the Plane',
#  'Linear Bounds between Contraction Coefficients for $f$-Divergences',
#  'On the Uniform Computational Content of the Baire Category Theorem',
#  'Decomposing 1-Sperner hypergraphs',
#  'Windrose Planarity: Embedding Graphs with Direction-Constrained Edges',
#  'Recovering a Hidden Community Beyond the Kesten-Stigum Threshold in\n  $O(|E| \\log^*|V|)$ Time',
#  'The grounding for Continuum',
#  'Avoiding fractional powers over the natural numbers',
#  "On the Definiteness of Earth Mover's Distance and Its Relation to Set\n  Intersection",
#  'On 1-Laplacian Elliptic Equations Modeling Magnetic Resonance Image\n  Rician Denoising',
#  'Fair and Square: Cake-Cutting in Two Dimensions',
#  'A Core Model for Choreographic Programming',
#  'Applied Choreographies',
#  'Dynamic Spectrum Sensing Through Accelerated Particle Swarm Optimization',
#  'A faster subquadratic algorithm for finding outlier correlations',
#  'Fair Cake-Cutting among Families',
#  'Surface Approximation via Asymptotic Optimal Geometric Partition',
#  'Random Irregular Block-hierarchical Networks: Algorithms for Computation\n  of Main Properties',
#  'Sketch-based Manga Retrieval using Manga109 Dataset',
#  'Dual Principal Component Pursuit',
#  'Old Bands, New Tracks---Revisiting the Band Model for Robust Hypothesis\n  Testing',
#  'A Graph Traversal Based Approach to Answer Non-Aggregation Questions\n  Over DBpedia',
#  'Distributed Robust Adaptive Frequency Control of Power Systems with\n  Dynamic Loads',
#  'Top-k Query Processing on Encrypted Databases with Strong Security\n  Guarantees',
#  'Monotonicity and Competitive Equilibrium in Cake-cutting',
#  'A First Practical Fully Homomorphic Crypto-Processor Design: The Secret\n  Computer is Nearly Here',
#  'Confidence Sets for the Source of a Diffusion in Regular Trees',
#  'Semi-Implicit Time Integration of Atmospheric Flows with\n  Characteristic-Based Flux Partitioning',
#  'Optimization as Estimation with Gaussian Processes in Bandit Settings',
#  'Triangular Alignment (TAME): A Tensor-based Approach for Higher-order\n  Network Alignment',
#  'Dual Free Adaptive Mini-batch SDCA for Empirical Risk Minimization',
#  'Quantum vs Classical Proofs and Subset Verification',
#  'Induced minors and well-quasi-ordering',
#  'Distributed Bare-Bones Communication in Wireless Networks',
#  'SLAP: Simultaneous Localization and Planning Under Uncertainty for\n  Physical Mobile Robots via Dynamic Replanning in Belief Space: Extended\n  version',
#  'Vehicle Color Recognition using Convolutional Neural Network',
#  'The Impossibility of Extending Random Dictatorship to Weak Preferences',
#  'Raptor Codes in the Low SNR Regime',
#  'Oblivious Fronthaul-Constrained Relay for a Gaussian Channel',
#  'Switching control for incremental stabilization of nonlinear systems via\n  contraction theory',
#  'Monotone Projection Lower Bounds from Extended Formulation Lower Bounds',
#  "My Reflections on the First Man vs. Machine No-Limit Texas Hold 'em\n  Competition",
#  'Effect of Gromov-hyperbolicity Parameter on Cuts and Expansions in\n  Graphs and Some Algorithmic Implications',
#  'Convexity in Tree Spaces',
#  'Phase Retrieval Using Unitary 2-Designs',
#  'Highway Long Short-Term Memory RNNs for Distant Speech Recognition',
#  'Prediction-Adaptation-Correction Recurrent Neural Networks for\n  Low-Resource Language Speech Recognition',
#  'Trace Refinement in Labelled Markov Decision Processes',
#  'Prediction of Dynamical time Series Using Kernel Based Regression and\n  Smooth Splines',
#  'Stable Matching Mechanisms are Not Obviously Strategy-Proof',
#  'Uniqueness, Spatial Mixing, and Approximation for Ferromagnetic 2-Spin\n  Systems',
#  'Minimizing Regret in Discounted-Sum Games',
#  'An Impossibility Result for Reconstruction in a Degree-Corrected\n  Planted-Partition Model',
#  'Toward an Efficient Multi-class Classification in an Open Universe',
#  'ProtNN: Fast and Accurate Nearest Neighbor Protein Function Prediction\n  based on Graph Embedding in Structural and Topological Space',
#  'Dynamic Gossip',
#  'Beating the Harmonic lower bound for online bin packing',
#  'Do Prices Coordinate Markets?',
#  'The wisdom of networks: A general adaptation and learning mechanism of\n  complex systems: The network core triggers fast responses to known stimuli;\n  innovations require the slow network periphery and are encoded by\n  core-remodeling',
#  'Privacy by Design: On the Formal Design and Conformance Check of\n  Personal Data Protection Policies and Architectures',
#  'Learn on Source, Refine on Target:A Model Transfer Learning Framework\n  with Random Forests',
#  'The height of piecewise-testable languages and the complexity of the\n  logic of subwords',
#  'Evaluation of the Intel Xeon Phi 7120 and NVIDIA K80 as accelerators for\n  two-dimensional panel codes',
#  'On Sylvester Colorings of Cubic Graphs',
#  'Statistical physics of inference: Thresholds and algorithms',
#  'Waste Makes Haste: Bounded Time Protocols for Envy-Free Cake Cutting\n  with Free Disposal',
#  'A Light CNN for Deep Face Representation with Noisy Labels',
#  'On the Combinatorial Version of the Slepian-Wolf Problem',
#  'ELDA: Towards Efficient and Lightweight Detection of Cache Pollution\n  Attacks in NDN',
#  'A general framework for Noetherian well ordered polynomial reductions',
#  'Reorganizing topologies of Steiner trees to accelerate their elimination',
#  'Eliminating Higher-Multiplicity Intersections, III. Codimension 2',
#  'Diffusion-like recommendation with enhanced similarity of objects',
#  'Game characterizations and lower cones in the Weihrauch degrees',
#  'The Game of Phishing',
#  'Hardness of RNA Folding Problem with Four Symbols',
#  'Heterogeneous Knowledge Transfer in Video Emotion Recognition,\n  Attribution and Summarization',
#  'Deep learning is a good steganalysis tool when embedding key is reused\n  for different images, even if there is a cover source-mismatch',
#  'NASCUP: Nucleic Acid Sequence Classification by Universal Probability',
#  'Cross-scale predictive dictionaries',
#  'Understanding Adversarial Training: Increasing Local Stability of Neural\n  Nets through Robust Optimization',
#  'Complexity and Approximability of Parameterized MAX-CSPs',
#  'Competitive Multi-scale Convolution',
#  'The Invisible Hand of Dynamic Market Pricing',
#  'Complex-Valued Gaussian Processes for Regression',
#  'BIRDNEST: Bayesian Inference for Ratings-Fraud Detection',
#  'EigenRec: Generalizing PureSVD for Effective and Efficient Top-N\n  Recommendations',
#  'Global Convergence of ADMM in Nonconvex Nonsmooth Optimization',
#  'Iterative Refinement of the Approximate Posterior for Directed Belief\n  Networks',
#  'On the robust hardness of Gr\\"obner basis computation',
#  'Universal halting times in optimization and machine learning',
#  'A Simple Hierarchical Pooling Data Structure for Loop Closure',
#  'Recurrent Semi-supervised Classification and Constrained Adversarial\n  Generation with Motion Capture Data',
#  'Convex Sparse Spectral Clustering: Single-view to Multi-view',
#  'A General Framework for the Design and Analysis of Sparse FIR Linear\n  Equalizers',
#  'Developing a High Performance Software Library with MPI and CUDA for\n  Matrix Computations',
#  'Face Alignment Across Large Poses: A 3D Solution',
#  'Super-Linear Gate and Super-Quadratic Wire Lower Bounds for Depth-Two\n  and Depth-Three Threshold Circuits',
#  'Max-Cut under Graph Constraints',
#  'Graph Isomorphism and Circuit Size',
#  'Welfare of Sequential Allocation Mechanisms for Indivisible Goods',
#  'Who Can Win a Single-Elimination Tournament?',
#  'A Modified Multiple OLS (m$^2$OLS) Algorithm for Signal Recovery in\n  Compressive Sensing',
#  'Real-Time Residential-Side Joint Energy Storage Management and Load\n  Scheduling with Renewable Integration',
#  'Loss Functions for Neural Networks for Image Processing',
#  'On the Degrees of Freedom of the Symmetric Multi-Relay MIMO Y Channel',
#  'Constant-approximation algorithms for highly connected multi-dominating\n  sets in unit disk graphs',
#  'The Alternating Stock Size Problem and the Gasoline Puzzle',
#  'Isomorphisms considered as equalities: Projecting functions and\n  enhancing partial application through and implementation of lambda+',
#  'Entropies of weighted sums in cyclic groups and an application to polar\n  codes',
#  'Technical Privacy Metrics: a Systematic Survey']

# %%
def article_names( doc ):
    for a in doc['OAI-PMH']['ListRecords']['record'].items:
        a#['header']['identifier'].split(":")[2]

# %%
h = article_names(doc)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-60-d5aaeae010f8> in <module>
# ----> 1 h = article_names(doc)
#
# <ipython-input-59-78afe1a0e4f2> in article_names(doc)
#       1 def article_names( doc ):
# ----> 2     for a in doc['OAI-PMH']['ListRecords']['record'].items:
#       3         a#['header']['identifier'].split(":")[2]
#
# AttributeError: 'list' object has no attribute 'items'

# %%
h

# %%
print(h)
# Out:
# None
